# %%
import pandas as pd

# %%
dowjones=pd.read_csv('indexes/dowjones_data.csv')
nasdaq=pd.read_csv('indexes/nasdaq_data.csv')
nifty=pd.read_csv('indexes/nifty50_data.csv')
sp=pd.read_csv('indexes/sp500_data.csv')
usd=pd.read_csv('indexes/us_dollar_index.csv')
usin=pd.read_csv('indexes/usd_inr_data.csv')

# %%
d=pd.DataFrame()

# %%
d['date']=pd.to_datetime(usd['date'])

# %%
d=pd.merge(d,dowjones,on='date',how='left')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 d=pd.merge(d,dowjones,on='date',how='left')
#
# File D:\Program_Files\Anaconda\Lib\site-packages\pandas\core\reshape\merge.py:170, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     155     return _cross_merge(
#     156         left_df,
#     157         right_df,
#    (...)
#     167         copy=copy,
#     168     )
#     169 else:
# --> 170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#     173         how=how,
#     174         on=on,
#     175         left_on=left_on,
#     176         right_on=right_on,
#     177         left_index=left_index,
#     178         right_index=right_index,
#     179         sort=sort,
#     180         suffixes=suffixes,
# ...

# %%
d.rename(columns={'close': 'dowjones'}, inplace=True)

# %%
d
# Out:
#             date
# 0     1973-03-01
# 1     1973-03-02
# 2     1973-03-05
# 3     1973-03-06
# 4     1973-03-07
# ...          ...
# 13176 2024-12-24
# 13177 2024-12-26
# 13178 2024-12-27
# 13179 2024-12-30
# 13180 2024-12-31
#
# [13181 rows x 1 columns]

# %%
dowjones=dowjones[['date','close']]

# %%
dowjones['date']=pd.to_datetime(dowjones['date'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6289 entries, 0 to 6288
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    6289 non-null   datetime64[ns]
#  1   close   6289 non-null   float64
#  2   high    6289 non-null   float64
#  3   low     6289 non-null   float64
#  4   open    6289 non-null   float64
#  5   volume  6289 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 294.9 KB

# %%
nasdaq=nasdaq[['date','close']]
nasdaq['date']=pd.to_datetime(nasdaq['date'])

d=pd.merge(d,nasdaq,on='date',how='left')
d.rename(columns={'close': 'nasdaq'}, inplace=True)

# %%
nifty=nifty[['date','close']]
nifty['date']=pd.to_datetime(nifty['date'])

d=pd.merge(d,nifty,on='date',how='left')
d.rename(columns={'close': 'nifty'}, inplace=True)
# Out:
# C:\Users\R A N J I T H\AppData\Local\Temp\ipykernel_7424\1337039634.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nifty['date']=pd.to_datetime(nifty['date'])

# %%
sp=sp[['date','close']]
sp['date']=pd.to_datetime(sp['date'])

d=pd.merge(d,sp,on='date',how='left')
d.rename(columns={'close': 'sp500'}, inplace=True)
# Out:
# C:\Users\R A N J I T H\AppData\Local\Temp\ipykernel_7424\200370566.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp['date']=pd.to_datetime(sp['date'])

# %%
usd=usd[['date','close']]
usd['date']=pd.to_datetime(usd['date'])

d=pd.merge(d,usd,on='date',how='left')
d.rename(columns={'close': 'dollarindex'}, inplace=True)
# Out:
# C:\Users\R A N J I T H\AppData\Local\Temp\ipykernel_7424\3308686871.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usd['date']=pd.to_datetime(usd['date'])

# %%
usin=usin[['date','close']]
usin['date']=pd.to_datetime(usin['date'])

d=pd.merge(d,usin,on='date',how='left')
d.rename(columns={'close': 'usdinr'}, inplace=True)
# Out:
# C:\Users\R A N J I T H\AppData\Local\Temp\ipykernel_7424\1501133886.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usin['date']=pd.to_datetime(usin['date'])

# %%
d.to_csv('indexes.csv',index=False)

# %%
data=pd.read_csv('indexes.csv')

# %%
data=data.merge(tcs,on='date')

# %%
data=data.drop(columns=['date'])

# %%
data
# Out:
#             date     dowjones        nasdaq        nifty        sp500  \
# 0     2006-02-21  11069.05957   2262.959961          NaN  1283.030029
# 1     2006-02-22  11137.16992   2283.169922          NaN  1292.670044
# 2     2006-02-23  11069.21973   2279.320068          NaN  1287.790039
# 3     2006-02-24  11061.84961   2287.040039          NaN  1289.430054
# 4     2006-02-27  11097.54980   2307.179932          NaN  1294.119995
# ...          ...          ...           ...          ...          ...
# 4508  2024-12-24  43297.03125  20031.130860  23727.65039  6040.040039
# 4509  2024-12-26  43325.80078  20020.359380  23750.19922  6037.589844
# 4510  2024-12-27  42992.21094  19722.029300  23813.40039  5970.839844
# 4511  2024-12-30  42573.73047  19486.789060  23644.90039  5906.939941
# 4512  2024-12-31  42544.21875  19310.789060  23644.80078  5881.629883
#
#       dollarindex     usdinr        close
# 0       90.550003  44.320000   150.309067
# ...

# %%
tcs=pd.read_csv("technical indicators/TCS.NS_indicators.csv")

# %%
import seaborn as sns
# df = data.drop(columns=['date'])  # Replace 'Date' with the actual name of your date column

plt.figure(figsize=(10, 8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
tcs
# Out:
#             date        close         high          low         open   volume  \
# 0     2006-02-21   150.309067   150.760174   148.964764   149.316630  2301240
# 1     2006-02-22   149.935577   150.669982   148.982844   150.669982  1156592
# 2     2006-02-23   150.720459   152.465340   149.767715   149.767715  4141584
# 3     2006-02-24   150.675308   151.572105   149.433860   150.693348  1097336
# 4     2006-02-27   152.506866   152.925496   150.345162   150.399293  2521112
# ...          ...          ...          ...          ...          ...      ...
# 4659  2025-01-20  4077.800049  4145.799805  4068.100098  4145.799805  1287799
# 4660  2025-01-21  4035.850098  4111.000000  4030.000000  4095.300049  1971591
# 4661  2025-01-22  4156.600098  4163.149902  4044.199951  4050.000000  2409223
# 4662  2025-01-23  4145.450195  4191.350098  4140.049805  4168.000000  1822998
# 4663  2025-01-24  4152.350098  4178.000000  4104.000000  4104.000000  1910099
#
# ...

# %%
tcs=tcs[['date','close']]

# %%
tcs
# Out:
#             date        close
# 0     2006-02-21   150.309067
# 1     2006-02-22   149.935577
# 2     2006-02-23   150.720459
# 3     2006-02-24   150.675308
# 4     2006-02-27   152.506866
# ...          ...          ...
# 4659  2025-01-20  4077.800049
# 4660  2025-01-21  4035.850098
# 4661  2025-01-22  4156.600098
# 4662  2025-01-23  4145.450195
# 4663  2025-01-24  4152.350098
#
# [4664 rows x 2 columns]
