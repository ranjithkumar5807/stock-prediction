# %%
import yfinance as yf
import pandas as pd
import pandas_ta as ta

# %%
data = pd.read_csv('tcs_data_with_indicators.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4697 entries, 0 to 4696
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         4697 non-null   object
#  1   close        4697 non-null   float64
#  2   high         4697 non-null   float64
#  3   low          4697 non-null   float64
#  4   open         4697 non-null   float64
#  5   volume       4697 non-null   int64
#  6   MACD         4672 non-null   float64
#  7   MACD_signal  4664 non-null   float64
#  8   MACD_hist    4664 non-null   float64
#  9   RSI          4683 non-null   float64
#  10  VWAP         4692 non-null   float64
#  11  BB_upper     4678 non-null   float64
#  12  BB_middle    4678 non-null   float64
#  13  BB_lower     4678 non-null   float64
#  14  OBV          4697 non-null   float64
#  15  ATR          4683 non-null   float64
#  16  EMA_5        4693 non-null   float64
#  17  EMA_8        4690 non-null   float64
# ...

# %%
data.describe()
# Out:
#              close         high          low         open        volume  \
# count  4697.000000  4697.000000  4697.000000  4697.000000  4.697000e+03
# mean   1356.019348  1370.199909  1342.159142  1356.503799  3.213884e+06
# std    1205.099396  1215.857703  1194.762291  1205.364270  2.707136e+06
# min      82.577103    85.954579    75.944296    82.910217  0.000000e+00
# 25%     362.450836   366.481484   354.906154   360.101493  1.801993e+06
# 50%    1005.877869  1014.828964   995.864976  1006.587246  2.547312e+06
# 75%    1969.886353  1984.860698  1951.050029  1969.952993  3.820678e+06
# max    4471.390137  4509.193819  4430.395122  4493.237606  8.806715e+07
#
#               MACD  MACD_signal    MACD_hist          RSI         VWAP  \
# count  4672.000000  4664.000000  4664.000000  4683.000000  4692.000000
# mean      5.986908     6.016680    -0.018489    53.190126  1357.057872
# std      25.737293    23.887984     8.587956    11.200252  1205.432402
# ...

# %%
data.isnull().sum()
# Out:
# date            0
# close           0
# high            0
# low             0
# open            0
# volume          0
# MACD           25
# MACD_signal    33
# MACD_hist      33
# RSI            14
# VWAP            5
# BB_upper       19
# BB_middle      19
# BB_lower       19
# OBV             0
# ATR            14
# EMA_5           4
# EMA_8           7
# EMA_13         12
# dtype: int64

# %%
#interpolation, forward fill, or dropping rows.

# %%
#Dropping Rows
dropped=data.dropna()

# %%
dropped.isnull().sum()
# Out:
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# MACD           0
# MACD_signal    0
# MACD_hist      0
# RSI            0
# VWAP           0
# BB_upper       0
# BB_middle      0
# BB_lower       0
# OBV            0
# ATR            0
# EMA_5          0
# EMA_8          0
# EMA_13         0
# dtype: int64

# %%
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt
# Out:
# UsageError: Line magic function `%` not found.

# %%
data.boxplot(by ='close', column =[''], grid = False)
# Out:
# <Axes: title={'center': 'RSI'}, xlabel='close'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.plot(data['date'], data['close'], label='Close Price')
plt.title('TCS Stock Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
import seaborn as sns
df = data.drop(columns=['date'])  # Replace 'Date' with the actual name of your date column

plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
